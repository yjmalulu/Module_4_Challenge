# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_data=Path("Resources/whale_returns.csv")
whale_df=pd.read_csv(whale_data,index_col='Date',parse_dates=True,infer_datetime_format=True)
whale_df.sort_index(inplace=True)
whale_df.head()
# Out:
# C:\Users\yjmal\AppData\Local\Temp\ipykernel_22700\3001493355.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   whale_df=pd.read_csv(whale_data,index_col='Date',parse_dates=True,infer_datetime_format=True)
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# ...

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df.dropna(inplace=True)
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_data=Path("Resources/algo_returns.csv")
algo_df=pd.read_csv(algo_data,index_col='Date',parse_dates=True,infer_datetime_format=True)
algo_df.sort_index(inplace=True)
algo_df.head()
# Out:
# C:\Users\yjmal\AppData\Local\Temp\ipykernel_22700\1869193108.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   algo_df=pd.read_csv(algo_data,index_col='Date',parse_dates=True,infer_datetime_format=True)
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df.dropna(inplace=True)
algo_df.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_data=Path("Resources/sp500_history.csv")
sp500_df=pd.read_csv(sp500_data,index_col='Date',parse_dates=True,infer_datetime_format=True)
sp500_df.sort_index(inplace=True)
sp500_df.head()
# Out:
# C:\Users\yjmal\AppData\Local\Temp\ipykernel_22700\574753319.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   sp500_df=pd.read_csv(sp500_data,index_col='Date',parse_dates=True,infer_datetime_format=True)
# C:\Users\yjmal\AppData\Local\Temp\ipykernel_22700\574753319.py:3: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   sp500_df=pd.read_csv(sp500_data,index_col='Date',parse_dates=True,infer_datetime_format=True)
#                Close
# Date
# 2012-10-01  $1444.49
# 2012-10-02  $1445.75
# 2012-10-03  $1450.99
# 2012-10-04  $1461.40
# 2012-10-05  $1460.93

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_df['Close']=sp500_df['Close'].str.replace('$','')
sp500_df['Close']=pd.to_numeric(sp500_df['Close'],errors='coerce')
sp500_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
sp500_daily_returns=sp500_df.pct_change()
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls
sp500_daily_returns.dropna(inplace=True)
sp500_daily_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_daily_returns.columns=['S&P 500']
sp500_daily_returns.head()
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_returns=pd.concat([whale_df,algo_df,sp500_daily_returns],axis='columns',join='inner')
combined_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
combined_returns.plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
cumulative_returns=(1+combined_returns).cumprod()
# Plot cumulative returns
cumulative_returns.plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_returns.plot.box(figsize=(20,10))
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
combined_returns_std=combined_returns.std()
combined_returns_std.sort_values(ascending=False,inplace=True)
combined_returns_std
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# S&P 500                        0.008554
# Algo 2                         0.008342
# SOROS FUND MANAGEMENT LLC      0.007895
# Algo 1                         0.007620
# PAULSON & CO.INC.              0.007023
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
daily_std_sp500=combined_returns_std[2]
# Determine which portfolios are riskier than the S&P 500
risker_portfolios=combined_returns_std[combined_returns_std>daily_std_sp500]
print(f"The portfolios which are riskier than the S&P 500:\n{risker_portfolios}")
# Out:
# The portfolios which are riskier than the S&P 500:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std=combined_returns_std*np.sqrt(252)
annualized_std
# Out:
# BERKSHIRE HATHAWAY INC         0.205077
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# S&P 500                        0.135786
# Algo 2                         0.132430
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 1                         0.120967
# PAULSON & CO.INC.              0.111488
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
combined_returns_std_21=combined_returns.rolling(window=21).std()
# Plot the rolling standard deviation
combined_returns_std_21.plot(figsize=(20,10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
return_correlation=combined_returns.corr()
# Display de correlation matrix
sns.heatmap(return_correlation,vmin=-1,vmax=1,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
portfolio_covariance = combined_returns.cov()

choosen_portfolio_covariance=portfolio_covariance.loc['S&P 500']
# Calculate variance of S&P 500
variance_sp500=combined_returns['S&P 500'].var()
#variance_sp500
# Computing beta
beta_portfolio = choosen_portfolio_covariance / variance_sp500


# Print beta values
print(beta_portfolio)

# Plotting beta trend 
import matplotlib.pyplot as plt
beta_portfolio.plot(kind='bar')
plt.title('Beta Trend of Portfolio Assets Compared to S&P 500')
plt.xlabel('Assets')
plt.ylabel('Beta Value')
plt.show()
# Out:
# SOROS FUND MANAGEMENT LLC      0.773375
# PAULSON & CO.INC.              0.549886
# TIGER GLOBAL MANAGEMENT LLC    0.794653
# BERKSHIRE HATHAWAY INC         1.134789
# Algo 1                         0.248991
# Algo 2                         0.837535
# S&P 500                        1.000000
# Name: S&P 500, dtype: float64

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
combined_returns.ewm(halflife = 21).std().plot(figsize = (20, 10))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios
sharpe_ratios = combined_returns.mean() *np.sqrt(252) / (combined_returns.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.022452
# PAULSON & CO.INC.             -0.030462
# TIGER GLOBAL MANAGEMENT LLC   -0.007626
# BERKSHIRE HATHAWAY INC         0.039170
# Algo 1                         0.086847
# Algo 2                         0.031583
# S&P 500                        0.040837
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios.plot(kind='bar')
plt.title('Sharpe Ratios of Different Portfolios')
plt.xlabel('Portfolios')
plt.ylabel('Sharpe Ratio')
plt.show()

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Algo1 outperforms both the market (S&P 500) and the whales portfolios.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
aapl_data=Path("Resources/aapl_historical.csv")
aapl_df=pd.read_csv(aapl_data,index_col='Trade DATE',parse_dates=True,infer_datetime_format=True)
aapl_df.sort_index(inplace=True)
aapl_df.head()
# Out:
# C:\Users\yjmal\AppData\Local\Temp\ipykernel_22700\964046710.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   aapl_df=pd.read_csv(aapl_data,index_col='Trade DATE',parse_dates=True,infer_datetime_format=True)
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   AAPL  188.59
# 2018-05-14   AAPL  188.15
# 2018-05-15   AAPL  186.44
# 2018-05-16   AAPL  188.18
# 2018-05-17   AAPL  186.99

# %%
# Reading data from 2nd stock
cost_data=Path("Resources/cost_historical.csv")
cost_df=pd.read_csv(cost_data,index_col='Trade DATE',parse_dates=True,infer_datetime_format=True)
cost_df.sort_index(inplace=True)
cost_df.head()
# Out:
# C:\Users\yjmal\AppData\Local\Temp\ipykernel_22700\1530719646.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   cost_df=pd.read_csv(cost_data,index_col='Trade DATE',parse_dates=True,infer_datetime_format=True)
#            Symbol    NOCP
# Trade DATE
# 2018-05-11   COST  195.76
# 2018-05-14   COST  195.88
# 2018-05-15   COST  195.48
# 2018-05-16   COST  198.71
# 2018-05-17   COST  199.60

# %%
# Reading data from 3rd stock
goog_data=Path("Resources/goog_historical.csv")
goog_df=pd.read_csv(goog_data,index_col='Trade DATE',parse_dates=True,infer_datetime_format=True)
goog_df.sort_index(inplace=True)
goog_df.head()
# Out:
# C:\Users\yjmal\AppData\Local\Temp\ipykernel_22700\1992110508.py:3: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   goog_df=pd.read_csv(goog_data,index_col='Trade DATE',parse_dates=True,infer_datetime_format=True)
#            Symbol     NOCP
# Trade DATE
# 2018-05-11   GOOG  1098.26
# 2018-05-14   GOOG  1100.20
# 2018-05-15   GOOG  1079.23
# 2018-05-16   GOOG  1081.77
# 2018-05-17   GOOG  1078.59

# %%
# Combine all stocks in a single DataFrame
combined_stock=pd.concat([aapl_df,cost_df,goog_df],axis='columns',join='inner')
combined_stock
# Out:
#            Symbol    NOCP Symbol    NOCP Symbol     NOCP
# Trade DATE
# 2018-05-11   AAPL  188.59   COST  195.76   GOOG  1098.26
# 2018-05-14   AAPL  188.15   COST  195.88   GOOG  1100.20
# 2018-05-15   AAPL  186.44   COST  195.48   GOOG  1079.23
# 2018-05-16   AAPL  188.18   COST  198.71   GOOG  1081.77
# 2018-05-17   AAPL  186.99   COST  199.60   GOOG  1078.59
# ...           ...     ...    ...     ...    ...      ...
# 2019-05-03   AAPL  211.75   COST  244.62   GOOG  1185.40
# 2019-05-06   AAPL  208.48   COST  244.23   GOOG  1189.39
# 2019-05-07   AAPL  202.86   COST  240.18   GOOG  1174.10
# 2019-05-08   AAPL  202.90   COST  241.34   GOOG  1166.27
# 2019-05-09   AAPL  200.72   COST  243.47   GOOG  1162.38
#
# [250 rows x 6 columns]

# %%
# Reset Date index

# %%
# Reorganize portfolio data by having a column per symbol
combined_stock.drop(columns=['Symbol'],inplace=True)
combined_stock.columns=['AAPL','COST','GOOG']
combined_stock.head()
# Out:
#               AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# Calculate daily returns
combined_stock_returns=combined_stock.pct_change()

# Drop NAs
combined_stock_returns.dropna(inplace=True)

# Display sample data
combined_stock_returns.head()
# Out:
#                 AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
stock_portfolio_return=combined_stock_returns.dot(weights)

# Display sample data
stock_portfolio_return.head()
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
all_portfolio_returns=pd.concat([combined_returns,stock_portfolio_return],axis='columns',join='inner')
all_portfolio_returns.rename(columns={0:'My stock portfolio returns'},inplace=True)
all_portfolio_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
# 2018-05-18                  -0.004357           -0.002672
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
# 2018-05-18                    -0.012832               -0.002212  0.002557
#
#               Algo 2   S&P 500  My stock portfolio returns
# 2018-05-14  0.001635  0.000884                    0.000015
# ...

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
all_portfolio_returns.dropna(inplace=True)
all_portfolio_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
# 2018-05-18                  -0.004357           -0.002672
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
# 2018-05-18                    -0.012832               -0.002212  0.002557
#
#               Algo 2   S&P 500  My stock portfolio returns
# 2018-05-14  0.001635  0.000884                    0.000015
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
annualized_std=all_portfolio_returns.std()*np.sqrt(252)
annualized_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.146675
# PAULSON & CO.INC.              0.116732
# TIGER GLOBAL MANAGEMENT LLC    0.232531
# BERKSHIRE HATHAWAY INC         0.247155
# Algo 1                         0.133704
# Algo 2                         0.139556
# S&P 500                        0.152054
# My stock portfolio returns     0.211496
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
annualized_std_rolling21=all_portfolio_returns.rolling(window=21).std()*np.sqrt(252)
annualized_std_rolling21.dropna(inplace=True)

# Plot rolling standard deviation
annualized_std_rolling21.plot(figsize=(20,10))
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
all_portfolio_returns_cor=all_portfolio_returns.corr()
sns.heatmap(all_portfolio_returns_cor,vmin=-1,vmax=1,annot=True)
# Out:
# <Axes: >

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
my_portfolio_cov_rol60=all_portfolio_returns['My stock portfolio returns'].rolling(window=60).cov(all_portfolio_returns['S&P 500'])
my_portfolio_cov_rol60.dropna(inplace=True)
var_sp500_rol60=all_portfolio_returns['S&P 500'].rolling(window=60).var()
var_sp500_rol60.dropna(inplace=True)
my_portflio_beta=my_portfolio_cov_rol60/var_sp500_rol60
my_portflio_beta.plot(figsize=(20,10))
# Out:
# <Axes: >

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratios2 = all_portfolio_returns.mean() *np.sqrt(252) / (all_portfolio_returns.std() * np.sqrt(252))
sharpe_ratios2
# Out:
# SOROS FUND MANAGEMENT LLC      0.027132
# PAULSON & CO.INC.              0.016299
# TIGER GLOBAL MANAGEMENT LLC   -0.065150
# BERKSHIRE HATHAWAY INC         0.010064
# Algo 1                         0.128235
# Algo 2                         0.005078
# S&P 500                        0.036840
# My stock portfolio returns     0.058781
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios2.plot(kind='bar')
plt.title('Sharpe Ratios of Different Portfolios')
plt.xlabel('Portfolios')
plt.ylabel('Sharpe Ratio')
plt.show()

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
Based on the Sharpe Ratio, my portfolio, which includes AAPL, GOOGL, and COST, performs less efficiently than Algo 1, yet significantly outperforms the S&P 500, Algo 2, and Whales.
